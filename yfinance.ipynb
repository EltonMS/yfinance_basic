# %% [markdown]
# <a href="https://colab.research.google.com/github/EltonMS/yfinance_basic/blob/main/yfinance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf

# %%
bb.head()
# Out:
#                        Date       Open       High        Low      Close  \
# 0 2023-05-08 00:00:00-03:00  19.171230  19.321281  18.959393  19.012354
# 1 2023-05-09 00:00:00-03:00  18.972636  19.157993  18.831410  18.954983
# 2 2023-05-10 00:00:00-03:00  18.977046  19.241841  18.800515  19.202122
# 3 2023-05-11 00:00:00-03:00  19.162404  19.691997  19.007941  19.594906
# 4 2023-05-12 00:00:00-03:00  19.440439  19.722888  19.374241  19.519878
#
#      Volume  Dividends  Stock Splits ticker
# 0  16195200        0.0           0.0  BBAS3
# 1  20231600        0.0           0.0  BBAS3
# 2  21044400        0.0           0.0  BBAS3
# 3  27159800        0.0           0.0  BBAS3
# 4  24417400        0.0           0.0  BBAS3

# %%
def carregar_dados(ticker):
  df = yf.Ticker(ticker).history("1y")
  df.reset_index(inplace=True)
  df['ticker'] = ticker.split(".")[0]
  return df

  petrobras = carregar_dados("PETR4.SA")
  vale = carregar_dados("VALE3.SA")
  bb = carregar_dados("BBAS3.SA")

  petrobras.head()
